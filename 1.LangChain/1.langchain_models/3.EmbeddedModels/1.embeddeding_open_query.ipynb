# %%
from dotenv import dotenv_values
env_file_vars = dotenv_values()
OPENAI_API_KEY = env_file_vars.get("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
model = OpenAIEmbeddings(model='text-embedding-3-large', dimensions=32)

# %%
result = model.embed_query("Delhi is the capital of India!")

# %%
print(result)
# Out:
# [0.09420371055603027, 0.19124390184879303, -0.139423668384552, 0.30590295791625977, -0.10118580609560013, 0.15251509845256805, -0.046392735093832016, -0.005710452329367399, -0.2620466947555542, 0.051329292356967926, -0.1722613275051117, 0.24546420574188232, -0.038892440497875214, -0.0892944261431694, -0.23324555158615112, -0.29368430376052856, -0.2616102993488312, 0.16146090626716614, 0.11564091593027115, -0.23782755434513092, 0.037365108728408813, -0.053211186081171036, 0.019841689616441727, -0.1915711760520935, -0.1407328099012375, 0.33448588848114014, 0.31463056802749634, -0.03913790360093117, -0.1111680120229721, -0.1747705191373825, 0.09251273423433304, 0.07102097570896149]
