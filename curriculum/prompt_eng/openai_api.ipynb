# %%
import my_mod

# %%
my_mod.func()
# Out:
# I am output from a module function!

# %%
print('Hello')
# Out:
# Hello

# %%
# pip install openai

# %%
from openai import OpenAI
my_api_key="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"
client = OpenAI(api_key=my_api_key)

response = client.responses.create(
  model="gpt-4.1",
  input="Tell me a three sentence bedtime story about a unicorn."
)

response.output_text
