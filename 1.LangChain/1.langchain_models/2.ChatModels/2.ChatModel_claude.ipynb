# %%
from dotenv import dotenv_values
env_file_vars = dotenv_values()
ANTHROPIC_API_KEY = env_file_vars.get("ANTHROPIC_API_KEY")

# %%
from langchain_anthropic import ChatAnthropic
model = ChatAnthropic(model="claude-sonnet-4-5")

# %%
ai_msg = model.invoke('What is the capital of India')

# %%
ai_msg.content
# Out:
# "The capital of India is **New Delhi**.\n\nNew Delhi serves as the seat of all three branches of the Government of India, including the Parliament. It's located within the larger metropolitan area of Delhi (National Capital Territory of Delhi)."
