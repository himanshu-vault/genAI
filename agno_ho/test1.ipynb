# %%
from agno.agent import Agent
from agno.models.anthropic import Claude
from agno.tools.hackernews import HackerNewsTools

agent = Agent(
    model=Claude(id="claude-sonnet-4-5"),
    tools=[HackerNewsTools()],
    markdown=True,
)
agent.print_response("Write a report on trending startups and products.", stream=True)
# Out:
# ERROR    ANTHROPIC_API_KEY not set. Please set the ANTHROPIC_API_KEY environment variable.
# ERROR    Unexpected error calling Claude API: "Could not resolve authentication method. Expected either api_key or
#          auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\models\anthropic\claude.py:360, in Claude.invoke_stream(self, messages, assistant_message, response_format, tools, tool_choice, run_response)
#     359 assistant_message.metrics.start_timer()
# --> 360 with self.get_client().messages.stream(
#     361     model=self.id,
#     362     messages=chat_messages,  # type: ignore
#     363     **request_kwargs,
#     364 ) as stream:
#     365     for chunk in stream:  # type: ignore
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\lib\streaming\_messages.py:154, in MessageStreamManager.__enter__(self)
#     153 def __enter__(self) -> MessageStream:
# --> 154     raw_stream = self.__api_request()
#     155     self.__stream = MessageStream(raw_stream)
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1323 opts = FinalRequestOptions.construct(
#    1324     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325 )
# -> 1326 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:1035, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034 remaining_retries = max_retries - retries_taken
# -> 1035 request = self._build_request(options, retries_taken=retries_taken)
#    1036 self._prepare_request(request)
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
#
# The above exception was the direct cause of the following exception:
#
# ModelProviderError                        Traceback (most recent call last)
# Cell In[3], line 10
#       3 from agno.tools.hackernews import HackerNewsTools
#       5 agent = Agent(
#       6     model=Claude(id="claude-sonnet-4-5"),
#       7     tools=[HackerNewsTools()],
#       8     markdown=True,
#       9 )
# ---> 10 agent.print_response("Write a report on trending startups and products.", stream=True)
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\agent\agent.py:9845, in Agent.print_response(self, input, session_id, session_state, user_id, audio, images, videos, files, stream, stream_events, stream_intermediate_steps, markdown, knowledge_filters, add_history_to_context, add_dependencies_to_context, dependencies, add_session_state_to_context, metadata, debug_mode, show_message, show_reasoning, show_full_reasoning, console, tags_to_include_in_markdown, **kwargs)
#    9842     stream_events = False if self.stream_events is None else self.stream_events
#    9844 if stream:
# -> 9845     print_response_stream(
#    9846         agent=self,
#    9847         input=input,
#    9848         session_id=session_id,
#    9849         session_state=session_state,
#    9850         user_id=user_id,
#    9851         audio=audio,
#    9852         images=images,
#    9853         videos=videos,
#    9854         files=files,
#    9855         stream_events=stream_events,
#    9856         knowledge_filters=knowledge_filters,
#    9857         debug_mode=debug_mode,
#    9858         markdown=markdown,
#    9859         show_message=show_message,
#    9860         show_reasoning=show_reasoning,
#    9861         show_full_reasoning=show_full_reasoning,
#    9862         tags_to_include_in_markdown=tags_to_include_in_markdown,
#    9863         console=console,
#    9864         add_history_to_context=add_history_to_context,
#    9865         dependencies=dependencies,
#    9866         add_dependencies_to_context=add_dependencies_to_context,
#    9867         add_session_state_to_context=add_session_state_to_context,
#    9868         metadata=metadata,
#    9869         **kwargs,
#    9870     )
#    9872 else:
#    9873     print_response(
#    9874         agent=self,
#    9875         input=input,
#    (...)   9897         **kwargs,
#    9898     )
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\utils\print_response\agent.py:87, in print_response_stream(agent, input, session_id, session_state, user_id, audio, images, videos, files, stream_events, stream_intermediate_steps, knowledge_filters, debug_mode, markdown, show_message, show_reasoning, show_full_reasoning, tags_to_include_in_markdown, console, add_history_to_context, dependencies, add_dependencies_to_context, add_session_state_to_context, metadata, **kwargs)
#      84 # Consider both stream_events and stream_intermediate_steps (deprecated)
#      85 stream_events = stream_events or stream_intermediate_steps
# ---> 87 for response_event in agent.run(
#      88     input=input,
#      89     session_id=session_id,
#      90     session_state=session_state,
#      91     user_id=user_id,
#      92     audio=audio,
#      93     images=images,
#      94     videos=videos,
#      95     files=files,
#      96     stream=True,
#      97     stream_events=stream_events,
#      98     knowledge_filters=knowledge_filters,
#      99     debug_mode=debug_mode,
#     100     add_history_to_context=add_history_to_context,
#     101     add_dependencies_to_context=add_dependencies_to_context,
#     102     add_session_state_to_context=add_session_state_to_context,
#     103     dependencies=dependencies,
#     104     metadata=metadata,
#     105     **kwargs,
#     106 ):
#     107     if isinstance(response_event, tuple(get_args(RunOutputEvent))):
#     108         if response_event.is_paused:  # type: ignore
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\agent\agent.py:1263, in Agent._run_stream(self, run_response, run_context, session, user_id, add_history_to_context, add_dependencies_to_context, add_session_state_to_context, response_format, stream_events, yield_run_output, debug_mode, **kwargs)
#    1261 # 6. Process model response
#    1262 if self.output_model is None:
# -> 1263     for event in self._handle_model_response_stream(
#    1264         session=session,
#    1265         run_response=run_response,
#    1266         run_messages=run_messages,
#    1267         tools=_tools,
#    1268         response_format=response_format,
#    1269         stream_events=stream_events,
#    1270         session_state=run_context.session_state,
#    1271     ):
#    1272         raise_if_cancelled(run_response.run_id)  # type: ignore
#    1273         yield event
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\agent\agent.py:4732, in Agent._handle_model_response_stream(self, session, run_response, run_messages, tools, response_format, stream_events, session_state)
#    4729     log_debug("Response model set, model response is not streamed.")
#    4730     stream_model_response = False
# -> 4732 for model_response_event in self.model.response_stream(
#    4733     messages=run_messages.messages,
#    4734     response_format=response_format,
#    4735     tools=tools,
#    4736     tool_choice=self.tool_choice,
#    4737     tool_call_limit=self.tool_call_limit,
#    4738     stream_model_response=stream_model_response,
#    4739     run_response=run_response,
#    4740     send_media_to_model=self.send_media_to_model,
#    4741 ):
#    4742     yield from self._handle_model_response_chunk(
#    4743         session=session,
#    4744         run_response=run_response,
#    (...)   4750         session_state=session_state,
#    4751     )
#    4753 # Determine reasoning completed
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\models\base.py:899, in Model.response_stream(self, messages, response_format, tools, tool_choice, tool_call_limit, stream_model_response, run_response, send_media_to_model)
#     896 model_response = ModelResponse()
#     897 if stream_model_response:
#     898     # Generate response
# --> 899     for response in self.process_response_stream(
#     900         messages=messages,
#     901         assistant_message=assistant_message,
#     902         stream_data=stream_data,
#     903         response_format=response_format,
#     904         tools=_tool_dicts,
#     905         tool_choice=tool_choice or self._tool_choice,
#     906         run_response=run_response,
#     907     ):
#     908         if self.cache_response and isinstance(response, ModelResponse):
#     909             streaming_responses.append(response)
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\models\base.py:833, in Model.process_response_stream(self, messages, assistant_message, stream_data, response_format, tools, tool_choice, run_response)
#     819 def process_response_stream(
#     820     self,
#     821     messages: List[Message],
#    (...)    827     run_response: Optional[Union[RunOutput, TeamRunOutput]] = None,
#     828 ) -> Iterator[ModelResponse]:
#     829     """
#     830     Process a streaming response from the model.
#     831     """
# --> 833     for response_delta in self.invoke_stream(
#     834         messages=messages,
#     835         assistant_message=assistant_message,
#     836         response_format=response_format,
#     837         tools=tools,
#     838         tool_choice=tool_choice or self._tool_choice,
#     839         run_response=run_response,
#     840     ):
#     841         for model_response_delta in self._populate_stream_data(
#     842             stream_data=stream_data,
#     843             model_response_delta=response_delta,
#     844         ):
#     845             yield model_response_delta
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\agno\models\anthropic\claude.py:383, in Claude.invoke_stream(self, messages, assistant_message, response_format, tools, tool_choice, run_response)
#     381 except Exception as e:
#     382     log_error(f"Unexpected error calling Claude API: {str(e)}")
# --> 383     raise ModelProviderError(message=str(e), model_name=self.name, model_id=self.id) from e
#
# ModelProviderError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
